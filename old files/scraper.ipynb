# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By

import bs4
import re

import pandas as pd

# %% [markdown]
# ## For a player

# %%
options = webdriver.EdgeOptions()
# options.add_argument('headless')
options.add_argument('inprivate')
driver = webdriver.Edge(options= options)

# %%
driver.get('https://qlstats.net/player/61491')

# %% [markdown]
# ### Cookie screen

# %%
def is_cookie_screen(driver : selenium.webdriver):
    '''A function to check if the given webpage is the 'accept cookies' screen.
    Regex matches the body of the '''
    element = driver.find_element(By.TAG_NAME, value = 'body')
    cookie_screen = re.compile(r'.*(To continue using qlstats, you need to agree to the use of cookies.\nAgree).*')
    if cookie_screen.search(element.text) is None:
        return False
    return True

# %%
#press the button
if is_cookie_screen(driver):
    try:
        button = driver.find_element(By.TAG_NAME, 'button')
        button.click()
    except:
        "Cookies could not be accepted, please recheck"

# %% [markdown]
# ### Scraping the player page

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')

# %%
# finding player name
player_name = soup.select_one('h2').text
print('Player name:\n{}'.format(player_name))

#for unavailable IDs:
if re.match(r"Sorry, that player wasn't found!", player_name):
    print("Player not found, can't proceed")

else:
    pass
    #TODO Scrape here
# Out:
# Player name:
# =*=Topgun=*=

# %% [markdown]
# ## ELSE tag here onwards
#
# - p_tab_list
# - player_info
# - games_played
# - stats
#
# The flow for gametypes is as follows:
# - Winrate
# - K/D ratio
# - Cap Ratio
# - ELO
# - B-ELO
# - Rank
# - Last Played
# - Games played
# - Favourite map

# %% [markdown]
# ### RegEx Extractors

# %%
stat_extractor = re.compile(r"Win Rate: (.*) Kill Ratio: (.*) Cap Ratio: (.*) Rating: (.*) B-Rating: (.*) Rank: (.*) Last Played: (.*) Games Played: (.*) Favorite Map: (.*)")
winrate_extractor = re.compile(r"([0-9]+\.?[0-9]*).*\((\d+).*, ([0-9]+).*")
kdRatio_extractor = re.compile(r"(\d+\.?\d+) \((\d+).*, (\d+).*")
capRatio_extractor = re.compile(r'(.*)')
elo_extractor = re.compile(r"([0-9]+) ± ([0-9]+).*, ([0-9]+).*")
rank_extractor = re.compile(r"([0-9]+) of ([0-9]+).*")

extractors = [winrate_extractor, kdRatio_extractor, capRatio_extractor, elo_extractor, elo_extractor, rank_extractor]

# %%
# parse information from the p tab
def extract_player_info(soup):
    p_tab_text = soup.select_one('p').text
    p_tab_list = list(map(str.strip, p_tab_text.split("\n")))
    p_tab_list = [x for x in p_tab_list if x != '']
    return p_tab_list



def extract_player_name_details(p_tab_list):
    player_info = {'name' : player_name}
    for x in p_tab_list:
        elements = x.split(": ")
        player_info[elements[0]] = elements[1]
    return player_info



# # press the overall button on the player page
# button = driver.find_element(By.CLASS_NAME, 'tab-overall')
# button.click()

def extract_game_info(soup):
    games_played = {}

    gametypes = soup.find('ul', id = 'gbtab').text
    gametypes = [x.strip() for x in gametypes.split('\n') if x != '']

    for i in range(len(gametypes)//2):
        t, n = gametypes[i*2], gametypes[2*i+1][1:-1]
        games_played[t] = int(n)

    games_played.pop('overall')
    return games_played


def parse_gametype_stats(data:tuple):
    '''Function for parsing the stats info given a tuple of
    - winrate
    - cap ratio
    - elo
    - b-elo
    - rank
    -last played
    - games played
    - fav map
    
    Returns a dictionary containing parsed info and keys:
    winrate, cap_ratio, elo (ordered-tuple as value), b-elo (ordered-tuple as value), rank (ordered-tuple as value), last_played, num_games, fav_map'''
    ret_dict = {}
    keys = ['winrate', 'kd_ratio', 'cap_ratio', 'elo', 'b-elo', 'rank', 'last_played', 'num_games', 'fav_map']
    for i in range(6):
        try:
            ext = extractors[i]
            to_parse = data[i]
            ret_dict[keys[i]] = ext.search(to_parse).groups()
        except:
            ret_dict[keys[i]] = '-'
    return ret_dict

def parse_stats(soup, gametypes):
    '''Parse and stores stats by gametype into a dictionary.
    
    Arguments: 
    - soup: the BS4 object
    - gametypes: a list of gametypes for extracting data. This can be acquired by scraping the 'gbtab' 
    list on a player's page on QLStats.
    
    Returns: A dictionary with keys as gametypes and values as the stats associated with them.
    The stats are extracted using RegEx.'''
    stats = {}
    # parse winrate and elo info
    for gt in gametypes:
        type_stats = soup.find('div', id = 'tab-{}'.format(gt)).text
        type_stats = type_stats.split('\n')
        type_stats = [x.strip() for x in type_stats if x.strip() != '']
        stats_as_string = " ".join(type_stats)

        res = stat_extractor.search(stats_as_string)
        #there is winrate, kill ratio, cap ratio, rating, b-rating, rank, last played games played favorite map
        stat_dict = parse_gametype_stats(res.groups())
        stats[gt] = stat_dict

    return stats





p_tab_list = extract_player_info(soup)
player_info = extract_player_name_details(p_tab_list)
games_played = extract_game_info(soup)
stats = parse_stats(soup, games_played.keys())
print(p_tab_list)
print(player_info)
print(games_played)
print(stats)
# Out:
# ['Region: Asia', 'Player ID: 61491', 'Steam ID: 76561197965738638', 'Joined: 2016-02-11   19:57:19', 'Status: active']
# {'name': '=*=Topgun=*=', 'Region': 'Asia', 'Player ID': '61491', 'Steam ID': '76561197965738638', 'Joined': '2016-02-11   19:57:19', 'Status': 'active'}
# {'ca': 15098, 'duel': 582, 'ffa': 391, 'dom': 33, 'ctf': 14, 'rr': 6, 'tdm': 5, 'harvester': 4, 'ft': 3, 'ad': 3, 'race': 2}
# {'ca': {'winrate': ('59.85', '9036', '6062'), 'kd_ratio': ('1.3', '181429', '139874'), 'cap_ratio': ('-',), 'elo': ('1341', '33', '10385'), 'b-elo': ('1216', '46', '479'), 'rank': ('9', '1515')}, 'duel': {'winrate': ('59.11', '344', '238'), 'kd_ratio': ('1.14', '6288', '5521'), 'cap_ratio': ('-',), 'elo': ('1310', '249', '343'), 'b-elo': ('738', '290', '1'), 'rank': '-'}, 'ffa': {'winrate': ('53.71', '210', '181'), 'kd_ratio': ('1.56', '16273', '10462'), 'cap_ratio': ('-',), 'elo': ('1825', '319', '18'), 'b-elo': ('1538', '93', '247'), 'rank': '-'}, 'dom': {'winrate': ('54.55', '18', '15'), 'kd_ratio': ('1.95', '360', '185'), 'cap_ratio': ('-',), 'elo': '-', 'b-elo': '-', 'rank': '-'}, 'ctf': {'winrate': ('42.86', '6', '8'), 'kd_ratio': ('1.53', '394', '258'), 'cap_ratio': ('-',), 'elo': ('1693', '242', '6'), 'b-elo': ('565', '209', '1'), 'rank': '-'}, 'rr': {'winrate': ('50.0', '3', '3'), 'kd_ratio': ('1.51', '71', '47'), 'cap_ratio': ('-',), 'elo': '-', 'b-elo': '-', 'rank': '-'}, 'tdm': {'winrate': ('80.0', '4', '1'), 'kd_ratio': ('1.41', '133', '94'), 'cap_ratio': ('-',), 'elo': ('1500', '300', '0'), 'b-elo': ('1185', '234', '1'), 'rank': '-'}, 'harvester': {'winrate': ('50.0', '2', '2'), 'kd_ratio': ('1.85', '61', '33'), 'cap_ratio': ('-',), 'elo': '-', 'b-elo': '-', 'rank': '-'}, 'ft': {'winrate': ('66.67', '2', '1'), 'kd_ratio': ('0.94', '49', '52'), 'cap_ratio': ('-',), 'elo': ('1500', '300', '0'), 'b-elo': ('1544', '165', '2'), 'rank': '-'}, 'ad': {'winrate': ('100.0', '3', '0'), 'kd_ratio': ('1.36', '19', '14'), 'cap_ratio': ('-',), 'elo': '-', 'b-elo': '-', 'rank': '-'}, 'race': {'winrate': ('0.0', '0', '2'), 'kd_ratio': ('0.0', '0', '20'), 'cap_ratio': ('-',), 'elo': '-', 'b-elo': '-', 'rank': '-'}}

# %% [markdown]
# Overall tab just has the latest/maximal values from the other tabs.

# %%
soup.findAll('table', class_= 'table table-hover table-condensed')
# Out:
# [<table class="table table-hover table-condensed">
#  <thead>
#  <tr>
#  <th>#</th>
#  <th></th>
#  <th>Played</th>
#  <th>Type</th>
#  <th>Server</th>
#  <th>Map</th>
#  <th>Result</th>
#  <th>Opponent</th>
#  <th>Rating</th>
#  <th title="Rating ± Uncertainty">Old Glicko</th>
#  <th title="Rating / Uncertainty">Glicko Change</th>
#  </tr>
#  </thead>
#  <tbody><tr><td>1</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8565965" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 22:10</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/44" title="Go to the detail page for this map">almostlost</a></td>
#  <td class="elodown">10:8 (#4)</td>
#  <td><a href="/player/-1"><span class="ql7">Anonymous 1</span></a></td>
#  <td>945 ± 53</td>
#  <td>1333 ± 33</td>
#  <td class="tdcenter">
#  <a href="/game/8565965" title="View detailed information about this game">
#  <span class="eloup">+8 / 0</span>
#  </a>
#  </td></tr><tr><td>2</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8565965" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 22:10</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/44" title="Go to the detail page for this map">almostlost</a></td>
#  <td class="eloup">10:8 (#-1)</td>
#  <td><a href="/player/-1"><span class="ql7">Anonymous 1</span></a></td>
#  <td>945 ± 53</td>
#  <td>1333 ± 33</td>
#  <td class="tdcenter">
#  <a href="/game/8565965" title="View detailed information about this game">
#  <span class="eloup">+8 / 0</span>
#  </a>
#  </td></tr><tr><td>3</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8565937" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 21:56</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/13" title="Go to the detail page for this map">campgrounds</a></td>
#  <td class="eloup">5:10 (#2)</td>
#  <td><a href="/player/23708"><span class="ql7">Addy</span></a></td>
#  <td>1302 ± 34</td>
#  <td>1335 ± 34</td>
#  <td class="tdcenter">
#  <a href="/game/8565937" title="View detailed information about this game">
#  <span class="elodown">-2 / 0</span>
#  </a>
#  </td></tr><tr><td>4</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8565905" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 21:40</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/265" title="Go to the detail page for this map">ra3map17c</a></td>
#  <td class="elodown">10:7 (#1)</td>
#  <td><a href="/player/213108"><span class="ql7">Xairo</span></a></td>
#  <td>1089 ± 66</td>
#  <td>1215 ± 47</td>
#  <td class="tdcenter">
#  <a href="/game/8565905" title="View detailed information about this game">
#  <span class="eloup">+1 / -1</span>
#  </a>
#     (<span title="B-Rating for custom settings/factories">B</span>)
#  </td></tr><tr><td>5</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8565882" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 21:28</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/47" title="Go to the detail page for this map">deadandgone</a></td>
#  <td class="elodown">10:5 (#2)</td>
#  <td><a href="/player/63562"><span class="ql7"></span><span class="ql7"></span><span class="ql1">A S U R A</span><span class="ql7"></span></a></td>
#  <td>1017 ± 52</td>
#  <td>1226 ± 48</td>
#  <td class="tdcenter">
#  <a href="/game/8565882" title="View detailed information about this game">
#  <span class="elodown">-11 / -1</span>
#  </a>
#     (<span title="B-Rating for custom settings/factories">B</span>)
#  </td></tr><tr><td>6</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8565866" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 21:15</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/187" title="Go to the detail page for this map">ra3map13b</a></td>
#  <td class="eloup">6:10 (#1)</td>
#  <td><a href="/player/-2"><span class="ql7">Anonymous 2</span></a></td>
#  <td></td>
#  <td></td>
#  <td class="tdcenter">
#  <a href="/game/8565866" title="View detailed information about this game">
#  <span class="eloneutral"><i class="glyphicon glyphicon-minus"></i></span>
#  </a>
#  </td></tr><tr><td>7</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8565842" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 21:03</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/32" title="Go to the detail page for this map">thunderstruck</a></td>
#  <td class="eloup">10:3 (#1)</td>
#  <td><a href="/player/332122"><span class="ql7">NaniBot</span></a></td>
#  <td></td>
#  <td></td>
#  <td class="tdcenter">
#  <a href="/game/8565842" title="View detailed information about this game">
#  <span class="eloneutral"><i class="glyphicon glyphicon-minus"></i></span>
#  </a>
#  </td></tr><tr><td>8</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8564152" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 01:03</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/107" title="Go to the detail page for this map">midlifecrisis</a></td>
#  <td class="eloup">10:2 (#1)</td>
#  <td><a href="/player/63562"><span class="ql7"></span><span class="ql7"></span><span class="ql1">A S U R A</span><span class="ql7"></span></a></td>
#  <td>1088 ± 35</td>
#  <td>1330 ± 31</td>
#  <td class="tdcenter">
#  <a href="/game/8564152" title="View detailed information about this game">
#  <span class="eloup">+5 / 0</span>
#  </a>
#  </td></tr><tr><td>9</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8564123" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 00:53</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/127" title="Go to the detail page for this map">hearth</a></td>
#  <td class="elodown">10:8 (#-1)</td>
#  <td><a href="/player/9944"><span class="ql7">TTV/GanasGaming</span></a></td>
#  <td>971 ± 86</td>
#  <td>1223 ± 47</td>
#  <td class="tdcenter">
#  <a href="/game/8564123" title="View detailed information about this game">
#  <span class="eloup">+3 / -1</span>
#  </a>
#     (<span title="B-Rating for custom settings/factories">B</span>)
#  </td></tr><tr><td>10</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8564123" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 00:53</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/127" title="Go to the detail page for this map">hearth</a></td>
#  <td class="eloup">10:8 (#3)</td>
#  <td><a href="/player/9944"><span class="ql7">TTV/GanasGaming</span></a></td>
#  <td>971 ± 86</td>
#  <td>1223 ± 47</td>
#  <td class="tdcenter">
#  <a href="/game/8564123" title="View detailed information about this game">
#  <span class="eloup">+3 / -1</span>
#  </a>
#     (<span title="B-Rating for custom settings/factories">B</span>)
#  </td></tr><tr><td>11</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8564091" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 00:40</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/104" title="Go to the detail page for this map">drunkenmummy</a></td>
#  <td class="eloup">5:10 (#5)</td>
#  <td><a href="/player/63562"><span class="ql7"></span><span class="ql7"></span><span class="ql1">A S U R A</span><span class="ql7"></span></a></td>
#  <td>1089 ± 35</td>
#  <td></td>
#  <td class="tdcenter">
#  <a href="/game/8564091" title="View detailed information about this game">
#  <span class="eloneutral"><i class="glyphicon glyphicon-minus"></i></span>
#  </a>
#  </td></tr><tr><td>12</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8564066" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 00:29</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/47" title="Go to the detail page for this map">deadandgone</a></td>
#  <td class="eloup">10:8 (#1)</td>
#  <td><a href="/player/220799"><span class="ql7">roomi</span></a></td>
#  <td>901 ± 68</td>
#  <td>1213 ± 48</td>
#  <td class="tdcenter">
#  <a href="/game/8564066" title="View detailed information about this game">
#  <span class="eloup">+10 / -1</span>
#  </a>
#     (<span title="B-Rating for custom settings/factories">B</span>)
#  </td></tr><tr><td>13</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8564028" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 00:14</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/20" title="Go to the detail page for this map">asylum</a></td>
#  <td class="elodown">6:10 (#2)</td>
#  <td><a href="/player/23708"><span class="ql7">Addy</span></a></td>
#  <td>1297 ± 32</td>
#  <td>1335 ± 32</td>
#  <td class="tdcenter">
#  <a href="/game/8564028" title="View detailed information about this game">
#  <span class="elodown">-5 / 0</span>
#  </a>
#  </td></tr><tr><td>14</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8563994" title="View detailed information about this game">view</a></td>
#  <td>2023-02-18 00:00</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/46" title="Go to the detail page for this map">hiddenfortress</a></td>
#  <td class="elodown">4:10 (#2)</td>
#  <td><a href="/player/13679"><span class="ql7">_yum</span></a></td>
#  <td>1038 ± 49</td>
#  <td>1334 ± 32</td>
#  <td class="tdcenter">
#  <a href="/game/8563994" title="View detailed information about this game">
#  <span class="eloup">+1 / 0</span>
#  </a>
#  </td></tr><tr><td>15</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8563930" title="View detailed information about this game">view</a></td>
#  <td>2023-02-17 23:31</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/1695" title="Go to the detail page for this map">overek</a></td>
#  <td class="eloup">10:7 (#2)</td>
#  <td><a href="/player/171710"><span class="ql7"></span><span class="ql5">Samooker</span><span class="ql7"></span></a></td>
#  <td>1324 ± 35</td>
#  <td>1329 ± 33</td>
#  <td class="tdcenter">
#  <a href="/game/8563930" title="View detailed information about this game">
#  <span class="eloup">+5 / 0</span>
#  </a>
#  </td></tr><tr><td>16</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8563893" title="View detailed information about this game">view</a></td>
#  <td>2023-02-17 23:14</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/19" title="Go to the detail page for this map">quarantine</a></td>
#  <td class="eloup">5:10 (#1)</td>
#  <td><a href="/player/23708"><span class="ql7">Addy</span></a></td>
#  <td>1307 ± 34</td>
#  <td>1321 ± 33</td>
#  <td class="tdcenter">
#  <a href="/game/8563893" title="View detailed information about this game">
#  <span class="eloup">+8 / 0</span>
#  </a>
#  </td></tr><tr><td>17</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8563860" title="View detailed information about this game">view</a></td>
#  <td>2023-02-17 22:55</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/13" title="Go to the detail page for this map">campgrounds</a></td>
#  <td class="eloup">10:4 (#1)</td>
#  <td><a href="/player/171710"><span class="ql7"></span><span class="ql5">Samooker</span><span class="ql7"></span></a></td>
#  <td>1341 ± 36</td>
#  <td>1311 ± 34</td>
#  <td class="tdcenter">
#  <a href="/game/8563860" title="View detailed information about this game">
#  <span class="eloup">+9 / 0</span>
#  </a>
#  </td></tr><tr><td>18</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8563834" title="View detailed information about this game">view</a></td>
#  <td>2023-02-17 22:39</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/26" title="Go to the detail page for this map">trinity</a></td>
#  <td class="eloup">6:10 (#4)</td>
#  <td><a href="/player/312322"><span class="ql7">HYDRAZINE</span></a></td>
#  <td>1363 ± 36</td>
#  <td>1309 ± 34</td>
#  <td class="tdcenter">
#  <a href="/game/8563834" title="View detailed information about this game">
#  <span class="eloup">+3 / 0</span>
#  </a>
#  </td></tr><tr><td>19</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8563804" title="View detailed information about this game">view</a></td>
#  <td>2023-02-17 22:23</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/44" title="Go to the detail page for this map">almostlost</a></td>
#  <td class="elodown">6:10 (#3)</td>
#  <td><a href="/player/23708"><span class="ql7">Addy</span></a></td>
#  <td>1295 ± 35</td>
#  <td>1314 ± 34</td>
#  <td class="tdcenter">
#  <a href="/game/8563804" title="View detailed information about this game">
#  <span class="elodown">-5 / 0</span>
#  </a>
#  </td></tr><tr><td>20</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8563783" title="View detailed information about this game">view</a></td>
#  <td>2023-02-17 22:09</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/47" title="Go to the detail page for this map">deadandgone</a></td>
#  <td class="elodown">6:10 (#2)</td>
#  <td><a href="/player/23708"><span class="ql7">Addy</span></a></td>
#  <td>1328 ± 66</td>
#  <td>1225 ± 49</td>
#  <td class="tdcenter">
#  <a href="/game/8563783" title="View detailed information about this game">
#  <span class="elodown">-12 / -1</span>
#  </a>
#     (<span title="B-Rating for custom settings/factories">B</span>)
#  </td></tr><tr><td>21</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8562102" title="View detailed information about this game">view</a></td>
#  <td>2023-02-16 23:32</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/265" title="Go to the detail page for this map">ra3map17c</a></td>
#  <td class="eloup">-999:2 (#1)</td>
#  <td><a href="/player/null"><span class="ql7">null</span></a></td>
#  <td></td>
#  <td></td>
#  <td class="tdcenter">
#  <a href="/game/8562102" title="View detailed information about this game">
#  <span class="eloneutral"><i class="glyphicon glyphicon-minus"></i></span>
#  </a>
#  </td></tr><tr><td>22</td>
#  <td class="tdcenter"><a class="btn btn-primary btn-small" href="/game/8562053" title="View detailed information about this game">view</a></td>
#  <td>2023-02-16 23:06</td>
#  <td><img alt="ca" height="24" src="/static/images/icons/24x24/ca.png" title="Clan Arena" width="24"/> ca</td>
#  <td><a href="/server/5935" title="Go to the detail page for this server">(India+Singapore+UAE) Topgun's CA Server w/crouchslide</a></td>
#  <td><a href="/map/19" title="Go to the detail page for this map">quarantine</a></td>
#  <td class="eloup">4:10 (#2)</td>
#  <td><a href="/player/23708"><span class="ql7">Addy</span></a></td>
#  <td>1303 ± 33</td>
#  <td>1307 ± 32</td>
#  <td class="tdcenter">
#  <a href="/game/8562053" title="View detailed information about this game">
#  <span class="eloup">+7 / 0</span>
#  </a>
#  </td></tr></tbody>
#  </table>]

# %% [markdown]
# ## Scrape match data

# %%
#click on 'more' button
try:
    btn = driver.find_element(By.LINK_TEXT, 'More...')
    btn.click()

    btn = driver.find_element(By.CSS_SELECTOR, '[alt="overall"]')
    btn.click()
except:
    print('Could not click the button')
# Out:
# Could not click the button

# %%
pd.read_html(driver.current_url, attrs = {'class': 'table table-hover table-condensed'})
# Out:
# [   Unnamed: 0              Played Type  \
#  0        view      11 minutes ago   ca
#  1        view      11 minutes ago   ca
#  2        view      25 minutes ago   ca
#  3        view      41 minutes ago   ca
#  4        view    about 1 hour ago   ca
#  5        view    about 1 hour ago   ca
#  6        view    about 1 hour ago   ca
#  7        view  about 21 hours ago   ca
#  8        view  about 21 hours ago   ca
#  9        view  about 21 hours ago   ca
#  10       view  about 22 hours ago   ca
#  11       view  about 22 hours ago   ca
#  12       view  about 22 hours ago   ca
#  13       view  about 22 hours ago   ca
#  14       view  about 23 hours ago   ca
#  15       view  about 23 hours ago   ca
#  16       view  about 23 hours ago   ca
#  17       view  about 24 hours ago   ca
#  18       view  about 24 hours ago   ca
#  19       view           1 day ago   ca
#
#                                                 Server             Map  \
#  0   (India+Singapore+UAE) Topgun's CA Server w/cro...      almostlost
#  1   (India+Singapore+UAE) Topgun's CA Server w/cro...      almostlost
#  2   (India+Singapore+UAE) Topgun's CA Server w/cro...     campgrounds
#  3   (India+Singapore+UAE) Topgun's CA Server w/cro...       ra3map17c
#  4   (India+Singapore+UAE) Topgun's CA Server w/cro...     deadandgone
#  5   (India+Singapore+UAE) Topgun's CA Server w/cro...       ra3map13b
#  6   (India+Singapore+UAE) Topgun's CA Server w/cro...   thunderstruck
#  7   (India+Singapore+UAE) Topgun's CA Server w/cro...   midlifecrisis
#  8   (India+Singapore+UAE) Topgun's CA Server w/cro...          hearth
#  9   (India+Singapore+UAE) Topgun's CA Server w/cro...          hearth
#  10  (India+Singapore+UAE) Topgun's CA Server w/cro...    drunkenmummy
#  11  (India+Singapore+UAE) Topgun's CA Server w/cro...     deadandgone
#  12  (India+Singapore+UAE) Topgun's CA Server w/cro...          asylum
#  13  (India+Singapore+UAE) Topgun's CA Server w/cro...  hiddenfortress
#  14  (India+Singapore+UAE) Topgun's CA Server w/cro...          overek
#  15  (India+Singapore+UAE) Topgun's CA Server w/cro...      quarantine
#  16  (India+Singapore+UAE) Topgun's CA Server w/cro...     campgrounds
#  17  (India+Singapore+UAE) Topgun's CA Server w/cro...         trinity
#  18  (India+Singapore+UAE) Topgun's CA Server w/cro...      almostlost
#  19  (India+Singapore+UAE) Topgun's CA Server w/cro...     deadandgone
#
#           Result         Opponent     Rating Old Glicko  Glicko Change
#  0   10:8  (#-1)      Anonymous 1   945 ± 53  1333 ± 33         +8 / 0
#  1    10:8  (#4)      Anonymous 1   945 ± 53  1333 ± 33         +8 / 0
#  2    5:10  (#2)             Addy  1302 ± 34  1335 ± 34         -2 / 0
#  3    10:7  (#1)            Xairo  1089 ± 66  1215 ± 47   +1 / -1  (B)
#  4    10:5  (#2)        A S U R A  1017 ± 52  1226 ± 48  -11 / -1  (B)
#  5    6:10  (#1)      Anonymous 2        NaN        NaN            NaN
#  6    10:3  (#1)          NaniBot        NaN        NaN            NaN
#  7    10:2  (#1)        A S U R A  1088 ± 35  1330 ± 31         +5 / 0
#  8    10:8  (#3)  TTV/GanasGaming   971 ± 86  1223 ± 47   +3 / -1  (B)
#  9   10:8  (#-1)  TTV/GanasGaming   971 ± 86  1223 ± 47   +3 / -1  (B)
#  10   5:10  (#5)        A S U R A  1089 ± 35        NaN            NaN
#  11   10:8  (#1)            roomi   901 ± 68  1213 ± 48  +10 / -1  (B)
#  12   6:10  (#2)             Addy  1297 ± 32  1335 ± 32         -5 / 0
#  13   4:10  (#2)             _yum  1038 ± 49  1334 ± 32         +1 / 0
#  14   10:7  (#2)         Samooker  1324 ± 35  1329 ± 33         +5 / 0
#  15   5:10  (#1)             Addy  1307 ± 34  1321 ± 33         +8 / 0
#  16   10:4  (#1)         Samooker  1341 ± 36  1311 ± 34         +9 / 0
#  17   6:10  (#4)        HYDRAZINE  1363 ± 36  1309 ± 34         +3 / 0
#  18   6:10  (#3)             Addy  1295 ± 35  1314 ± 34         -5 / 0
#  19   6:10  (#2)             Addy  1328 ± 66  1225 ± 49  -12 / -1  (B)  ]

# %% [markdown]
# ### Shut down the browser

# %%
# driver.close()
